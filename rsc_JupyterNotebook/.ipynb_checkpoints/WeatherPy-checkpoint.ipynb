# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
import pytemperature
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)


# ######################################################################
# #FOR TESTING ONLY:
# cities = cities[0:10]
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#1: define the basics:
base_url = 'http://api.openweathermap.org/data/2.5/weather?'
query_url = f"{base_url}appid={api_key}&q="


print('Beginning Data Retrieval')
# records_json = []
city_list = []
cloudiness_list = []
country_list = []
unfmt_date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_t_list = []
windspeed_list = []


#2: loop through each city and get their data:
rec_no = 1
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
#         records_json.append(response)
        city_list.append(response['name'])
        cloudiness_list.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        unfmt_date_list.append(response['dt']) 
        humidity_list.append(response['main']['humidity'])
        lat_list.append(response['coord']['lat'])
        lng_list.append(response['coord']['lon'])
        max_t_list.append(response['main']['temp_max'])
        windspeed_list.append(response['wind']['speed'])

        print(f"Processing Record {rec_no} of {len(cities)} | {city}")
    except:
        print(f"City ({city}) not found. Skipping to the next city")
    
    rec_no += 1
# Out:
# Beginning Data Retrieval
# Processing Record 1 of 593 | komsomolskiy
# Processing Record 2 of 593 | port alfred
# Processing Record 3 of 593 | valera
# City (inderborskiy) not found. Skipping to the next city
# Processing Record 5 of 593 | vanimo
# Processing Record 6 of 593 | bathsheba
# Processing Record 7 of 593 | flin flon
# Processing Record 8 of 593 | rikitea
# Processing Record 9 of 593 | albany
# Processing Record 10 of 593 | mar del plata
# Processing Record 11 of 593 | georgetown
# Processing Record 12 of 593 | port lincoln
# Processing Record 13 of 593 | busselton
# Processing Record 14 of 593 | cedar city
# Processing Record 15 of 593 | san patricio
# Processing Record 16 of 593 | severo-kurilsk
# Processing Record 17 of 593 | constitucion
# Processing Record 18 of 593 | nokaneng
# Processing Record 19 of 593 | jamestown
# Processing Record 20 of 593 | bredasdorp
# City (azimur) not found. Skipping to the next city
# Processing Record 22 of 593 | bluff
# Processing Record 23 of 593 | ribeira grande
# Processing Record 24 of 593 | comodoro rivadavia
# Processing Record 25 of 593 | arraial do cabo
# Processing Record 26 of 593 | mataura
# Processing Record 27 of 593 | te anau
# Processing Record 28 of 593 | barinas
# Processing Record 29 of 593 | coos bay
# Processing Record 30 of 593 | belmonte
# Processing Record 31 of 593 | chokurdakh
# Processing Record 32 of 593 | nikolskoye
# City (bac can) not found. Skipping to the next city
# Processing Record 34 of 593 | barrow
# Processing Record 35 of 593 | kirakira
# Processing Record 36 of 593 | nantucket
# City (asau) not found. Skipping to the next city
# Processing Record 38 of 593 | lompoc
# Processing Record 39 of 593 | navahrudak
# Processing Record 40 of 593 | husavik
# Processing Record 41 of 593 | thompson
# City (tsihombe) not found. Skipping to the next city
# Processing Record 43 of 593 | keti bandar
# Processing Record 44 of 593 | luderitz
# Processing Record 45 of 593 | skelleftea
# Processing Record 46 of 593 | tateyama
# Processing Record 47 of 593 | troitsko-pechorsk
# Processing Record 48 of 593 | saint-philippe
# Processing Record 49 of 593 | atuona
# Processing Record 50 of 593 | sambava
# Processing Record 51 of 593 | puerto leguizamo
# Processing Record 52 of 593 | mayo
# Processing Record 53 of 593 | port macquarie
# Processing Record 54 of 593 | kodiak
# Processing Record 55 of 593 | cape town
# Processing Record 56 of 593 | saskylakh
# Processing Record 57 of 593 | ixtapa
# Processing Record 58 of 593 | bonavista
# City (marcona) not found. Skipping to the next city
# Processing Record 60 of 593 | ushuaia
# Processing Record 61 of 593 | castro
# Processing Record 62 of 593 | port elizabeth
# Processing Record 63 of 593 | punta arenas
# Processing Record 64 of 593 | new norfolk
# Processing Record 65 of 593 | hermanus
# Processing Record 66 of 593 | esperance
# City (taolanaro) not found. Skipping to the next city
# Processing Record 68 of 593 | tsogni
# Processing Record 69 of 593 | cassia
# Processing Record 70 of 593 | carutapera
# Processing Record 71 of 593 | bethel
# Processing Record 72 of 593 | balurghat
# Processing Record 73 of 593 | talnakh
# Processing Record 74 of 593 | cruz alta
# Processing Record 75 of 593 | longyearbyen
# Processing Record 76 of 593 | chuy
# Processing Record 77 of 593 | qaanaaq
# Processing Record 78 of 593 | kiama
# Processing Record 79 of 593 | sola
# Processing Record 80 of 593 | aland
# Processing Record 81 of 593 | hobart
# Processing Record 82 of 593 | jackson
# Processing Record 83 of 593 | puerto ayora
# Processing Record 84 of 593 | douglas
# Processing Record 85 of 593 | banda aceh
# Processing Record 86 of 593 | guerrero negro
# Processing Record 87 of 593 | singleton
# City (halalo) not found. Skipping to the next city
# Processing Record 89 of 593 | vila velha
# Processing Record 90 of 593 | san jose
# City (bengkulu) not found. Skipping to the next city
# Processing Record 92 of 593 | sitka
# Processing Record 93 of 593 | cayenne
# Processing Record 94 of 593 | sao joao da barra
# Processing Record 95 of 593 | adamas
# Processing Record 96 of 593 | port augusta
# Processing Record 97 of 593 | dickinson
# Processing Record 98 of 593 | ponta do sol
# City (vaitupu) not found. Skipping to the next city
# Processing Record 100 of 593 | freeport
# Processing Record 101 of 593 | pacific grove
# Processing Record 102 of 593 | phan thiet
# Processing Record 103 of 593 | vaini
# Processing Record 104 of 593 | los llanos de aridane
# Processing Record 105 of 593 | iqaluit
# Processing Record 106 of 593 | puqi
# Processing Record 107 of 593 | victoria
# Processing Record 108 of 593 | ous
# Processing Record 109 of 593 | zhucheng
# City (nizhneyansk) not found. Skipping to the next city
# Processing Record 111 of 593 | tuktoyaktuk
# Processing Record 112 of 593 | norman wells
# Processing Record 113 of 593 | geraldton
# Processing Record 114 of 593 | jiangyou
# Processing Record 115 of 593 | sao filipe
# Processing Record 116 of 593 | upernavik
# Processing Record 117 of 593 | luau
# Processing Record 118 of 593 | kodarma
# Processing Record 119 of 593 | kapaa
# Processing Record 120 of 593 | faanui
# Processing Record 121 of 593 | cidreira
# Processing Record 122 of 593 | brae
# Processing Record 123 of 593 | ahipara
# City (hihifo) not found. Skipping to the next city
# Processing Record 125 of 593 | arona
# Processing Record 126 of 593 | sergiyev posad
# Processing Record 127 of 593 | bilma
# Processing Record 128 of 593 | mankono
# Processing Record 129 of 593 | harper
# Processing Record 130 of 593 | pangnirtung
# Processing Record 131 of 593 | alyangula
# Processing Record 132 of 593 | baculin
# Processing Record 133 of 593 | taltal
# Processing Record 134 of 593 | narsaq
# City (deh rawud) not found. Skipping to the next city
# Processing Record 136 of 593 | lodja
# Processing Record 137 of 593 | marawi
# Processing Record 138 of 593 | half moon bay
# City (phrai bung) not found. Skipping to the next city
# Processing Record 140 of 593 | provideniya
# Processing Record 141 of 593 | cabo san lucas
# Processing Record 142 of 593 | cherskiy
# City (thano bula khan) not found. Skipping to the next city
# Processing Record 144 of 593 | aklavik
# Processing Record 145 of 593 | port blair
# Processing Record 146 of 593 | eureka
# Processing Record 147 of 593 | pakenham
# Processing Record 148 of 593 | isangel
# Processing Record 149 of 593 | valdemarpils
# Processing Record 150 of 593 | puerto cabezas
# City (sorvag) not found. Skipping to the next city
# Processing Record 152 of 593 | avarua
# Processing Record 153 of 593 | siddapur
# Processing Record 154 of 593 | peleduy
# Processing Record 155 of 593 | manjacaze
# Processing Record 156 of 593 | nanortalik
# Processing Record 157 of 593 | honiara
# Processing Record 158 of 593 | palmer
# Processing Record 159 of 593 | butaritari
# City (illoqqortoormiut) not found. Skipping to the next city
# Processing Record 161 of 593 | isla vista
# Processing Record 162 of 593 | kununurra
# Processing Record 163 of 593 | kruisfontein
# Processing Record 164 of 593 | inuvik
# City (warqla) not found. Skipping to the next city
# Processing Record 166 of 593 | hit
# Processing Record 167 of 593 | the valley
# Processing Record 168 of 593 | camapua
# Processing Record 169 of 593 | mahenge
# Processing Record 170 of 593 | turbana
# Processing Record 171 of 593 | kawalu
# Processing Record 172 of 593 | cheyenne
# Processing Record 173 of 593 | kaitangata
# Processing Record 174 of 593 | shingu
# Processing Record 175 of 593 | hithadhoo
# Processing Record 176 of 593 | khandyga
# City (belushya guba) not found. Skipping to the next city
# Processing Record 178 of 593 | kem
# Processing Record 179 of 593 | riyadh
# Processing Record 180 of 593 | puri
# Processing Record 181 of 593 | makamba
# Processing Record 182 of 593 | san quintin
# Processing Record 183 of 593 | mattawa
# Processing Record 184 of 593 | hilo
# City (eskasem) not found. Skipping to the next city
# Processing Record 186 of 593 | airai
# City (tumannyy) not found. Skipping to the next city
# Processing Record 188 of 593 | hofn
# Processing Record 189 of 593 | kiunga
# Processing Record 190 of 593 | kampene
# Processing Record 191 of 593 | kavaratti
# Processing Record 192 of 593 | dankov
# Processing Record 193 of 593 | carnarvon
# Processing Record 194 of 593 | rocha
# Processing Record 195 of 593 | megion
# Processing Record 196 of 593 | semikarakorsk
# Processing Record 197 of 593 | sakmara
# Processing Record 198 of 593 | grindavik
# Processing Record 199 of 593 | coquimbo
# Processing Record 200 of 593 | russell
# Processing Record 201 of 593 | mount isa
# Processing Record 202 of 593 | khandagayty
# Processing Record 203 of 593 | aasiaat
# Processing Record 204 of 593 | tabou
# Processing Record 205 of 593 | kastamonu
# Processing Record 206 of 593 | chapais
# Processing Record 207 of 593 | soe
# Processing Record 208 of 593 | juazeiro
# Processing Record 209 of 593 | nenjiang
# Processing Record 210 of 593 | anadyr
# Processing Record 211 of 593 | cooma
# Processing Record 212 of 593 | evensk
# Processing Record 213 of 593 | san matias
# Processing Record 214 of 593 | ust-nera
# Processing Record 215 of 593 | bubaque
# Processing Record 216 of 593 | horsham
# City (sentyabrskiy) not found. Skipping to the next city
# Processing Record 218 of 593 | saint-augustin
# Processing Record 219 of 593 | kokopo
# Processing Record 220 of 593 | poum
# Processing Record 221 of 593 | xiongzhou
# City (ust-kamchatsk) not found. Skipping to the next city
# Processing Record 223 of 593 | rio gallegos
# Processing Record 224 of 593 | oriximina
# Processing Record 225 of 593 | san cristobal
# Processing Record 226 of 593 | kahului
# Processing Record 227 of 593 | yellowknife
# Processing Record 228 of 593 | quatre cocos
# Processing Record 229 of 593 | waihi beach
# Processing Record 230 of 593 | albacete
# Processing Record 231 of 593 | bambanglipuro
# Processing Record 232 of 593 | touros
# Processing Record 233 of 593 | saint anthony
# Processing Record 234 of 593 | lufilufi
# City (moulmeingyun) not found. Skipping to the next city
# Processing Record 236 of 593 | fortuna
# Processing Record 237 of 593 | fairbanks
# Processing Record 238 of 593 | sunrise manor
# Processing Record 239 of 593 | nanakuli
# Processing Record 240 of 593 | lebu
# Processing Record 241 of 593 | codrington
# Processing Record 242 of 593 | darab
# Processing Record 243 of 593 | rudnogorsk
# Processing Record 244 of 593 | tasiilaq
# Processing Record 245 of 593 | miri
# Processing Record 246 of 593 | hualmay
# Processing Record 247 of 593 | solwezi
# Processing Record 248 of 593 | bukachacha
# Processing Record 249 of 593 | bambous virieux
# Processing Record 250 of 593 | opuwo
# Processing Record 251 of 593 | hasaki
# Processing Record 252 of 593 | east london
# Processing Record 253 of 593 | muswellbrook
# Processing Record 254 of 593 | miles city
# Processing Record 255 of 593 | pathein
# Processing Record 256 of 593 | pochutla
# Processing Record 257 of 593 | lorengau
# Processing Record 258 of 593 | golubitskaya
# Processing Record 259 of 593 | aksarka
# Processing Record 260 of 593 | kutum
# City (louisbourg) not found. Skipping to the next city
# City (saleaula) not found. Skipping to the next city
# Processing Record 263 of 593 | saldanha
# Processing Record 264 of 593 | vanavara
# Processing Record 265 of 593 | laguna
# Processing Record 266 of 593 | luanda
# Processing Record 267 of 593 | tual
# Processing Record 268 of 593 | ueno
# Processing Record 269 of 593 | praia da vitoria
# Processing Record 270 of 593 | kumi
# City (barentsburg) not found. Skipping to the next city
# Processing Record 272 of 593 | makakilo city
# Processing Record 273 of 593 | havre-saint-pierre
# Processing Record 274 of 593 | inzer
# Processing Record 275 of 593 | ginda
# Processing Record 276 of 593 | sovetskiy
# Processing Record 277 of 593 | khatanga
# Processing Record 278 of 593 | sidney
# Processing Record 279 of 593 | chumikan
# Processing Record 280 of 593 | dunedin
# Processing Record 281 of 593 | klyuchevskiy
# Processing Record 282 of 593 | souillac
# Processing Record 283 of 593 | yulara
# Processing Record 284 of 593 | curup
# Processing Record 285 of 593 | bonnyville
# Processing Record 286 of 593 | vila franca do campo
# Processing Record 287 of 593 | sandovo
# City (concepcion del norte) not found. Skipping to the next city
# Processing Record 289 of 593 | ziro
# Processing Record 290 of 593 | torbay
# Processing Record 291 of 593 | alto araguaia
# Processing Record 292 of 593 | ostrovnoy
# Processing Record 293 of 593 | porto novo
# Processing Record 294 of 593 | alberton
# Processing Record 295 of 593 | charters towers
# Processing Record 296 of 593 | kurdzhinovo
# Processing Record 297 of 593 | tvrdosin
# City (wulanhaote) not found. Skipping to the next city
# Processing Record 299 of 593 | nalut
# Processing Record 300 of 593 | pevek
# Processing Record 301 of 593 | mount gambier
# Processing Record 302 of 593 | kisangani
# Processing Record 303 of 593 | deniliquin
# Processing Record 304 of 593 | sobolevo
# Processing Record 305 of 593 | hami
# Processing Record 306 of 593 | abu zabad
# Processing Record 307 of 593 | aguai
# Processing Record 308 of 593 | manresa
# City (krasnoselkup) not found. Skipping to the next city
# Processing Record 310 of 593 | jalu
# Processing Record 311 of 593 | kysyl-syr
# Processing Record 312 of 593 | sikasso
# City (dzhusaly) not found. Skipping to the next city
# Processing Record 314 of 593 | traverse city
# Processing Record 315 of 593 | el cobre
# Processing Record 316 of 593 | dikson
# Processing Record 317 of 593 | mahebourg
# Processing Record 318 of 593 | amasia
# Processing Record 319 of 593 | sistranda
# Processing Record 320 of 593 | skibbereen
# Processing Record 321 of 593 | tiksi
# Processing Record 322 of 593 | gat
# Processing Record 323 of 593 | nokia
# City (tidore) not found. Skipping to the next city
# Processing Record 325 of 593 | inhambane
# Processing Record 326 of 593 | faya
# Processing Record 327 of 593 | arlit
# Processing Record 328 of 593 | kaeo
# Processing Record 329 of 593 | vestmannaeyjar
# Processing Record 330 of 593 | petrovsk-zabaykalskiy
# City (amderma) not found. Skipping to the next city
# Processing Record 332 of 593 | tiarei
# Processing Record 333 of 593 | ponta delgada
# Processing Record 334 of 593 | lagoa
# Processing Record 335 of 593 | kazachinskoye
# City (xiangdong) not found. Skipping to the next city
# Processing Record 337 of 593 | huambo
# Processing Record 338 of 593 | kassala
# Processing Record 339 of 593 | marquette
# Processing Record 340 of 593 | santiago del estero
# City (lugovskiy) not found. Skipping to the next city
# Processing Record 342 of 593 | sofiyivka
# Processing Record 343 of 593 | ambon
# Processing Record 344 of 593 | ouesso
# Processing Record 345 of 593 | roald
# Processing Record 346 of 593 | nishihara
# Processing Record 347 of 593 | klaksvik
# Processing Record 348 of 593 | labytnangi
# City (umm durman) not found. Skipping to the next city
# Processing Record 350 of 593 | shellbrook
# Processing Record 351 of 593 | severo-yeniseyskiy
# Processing Record 352 of 593 | iberia
# Processing Record 353 of 593 | rawson
# City (grand river south east) not found. Skipping to the next city
# Processing Record 355 of 593 | mareeba
# Processing Record 356 of 593 | fairview
# City (phan rang) not found. Skipping to the next city
# Processing Record 358 of 593 | oktyabrsk
# Processing Record 359 of 593 | tongliao
# Processing Record 360 of 593 | halifax
# Processing Record 361 of 593 | alexandria
# Processing Record 362 of 593 | kilindoni
# City (akyab) not found. Skipping to the next city
# City (talipparamba) not found. Skipping to the next city
# Processing Record 365 of 593 | srednekolymsk
# Processing Record 366 of 593 | galle
# Processing Record 367 of 593 | sterling
# Processing Record 368 of 593 | banes
# Processing Record 369 of 593 | sume
# City (attawapiskat) not found. Skipping to the next city
# City (gurgan) not found. Skipping to the next city
# Processing Record 372 of 593 | orikum
# City (himora) not found. Skipping to the next city
# City (bargal) not found. Skipping to the next city
# Processing Record 375 of 593 | peace river
# Processing Record 376 of 593 | brewster
# Processing Record 377 of 593 | micheweni
# Processing Record 378 of 593 | tuatapere
# Processing Record 379 of 593 | sayansk
# Processing Record 380 of 593 | atchison
# Processing Record 381 of 593 | oparino
# Processing Record 382 of 593 | malyn
# Processing Record 383 of 593 | puerto ayacucho
# Processing Record 384 of 593 | alofi
# Processing Record 385 of 593 | constanza
# Processing Record 386 of 593 | hervey bay
# Processing Record 387 of 593 | aksha
# Processing Record 388 of 593 | werda
# Processing Record 389 of 593 | wamba
# Processing Record 390 of 593 | wajima
# City (samusu) not found. Skipping to the next city
# City (gogrial) not found. Skipping to the next city
# Processing Record 393 of 593 | saint george
# City (kuche) not found. Skipping to the next city
# Processing Record 395 of 593 | yar-sale
# Processing Record 396 of 593 | bima
# Processing Record 397 of 593 | barbastro
# Processing Record 398 of 593 | dwarka
# Processing Record 399 of 593 | coihaique
# Processing Record 400 of 593 | smolyaninovo
# Processing Record 401 of 593 | deputatskiy
# Processing Record 402 of 593 | maltahohe
# Processing Record 403 of 593 | mbuji-mayi
# Processing Record 404 of 593 | sydney
# Processing Record 405 of 593 | libreville
# Processing Record 406 of 593 | del rio
# Processing Record 407 of 593 | katsuura
# Processing Record 408 of 593 | lavrentiya
# Processing Record 409 of 593 | general roca
# Processing Record 410 of 593 | colares
# City (kamenskoye) not found. Skipping to the next city
# Processing Record 412 of 593 | natal
# City (galgani) not found. Skipping to the next city
# Processing Record 414 of 593 | itarema
# Processing Record 415 of 593 | vostok
# Processing Record 416 of 593 | kandrian
# Processing Record 417 of 593 | eyl
# Processing Record 418 of 593 | chulym
# Processing Record 419 of 593 | najran
# Processing Record 420 of 593 | kushima
# Processing Record 421 of 593 | coruripe
# Processing Record 422 of 593 | puksoozero
# Processing Record 423 of 593 | macherla
# Processing Record 424 of 593 | bandarbeyla
# Processing Record 425 of 593 | ahuimanu
# Processing Record 426 of 593 | pokhara
# Processing Record 427 of 593 | zhezkazgan
# Processing Record 428 of 593 | lotofaga
# Processing Record 429 of 593 | lhokseumawe
# Processing Record 430 of 593 | arrifes
# City (solovetskiy) not found. Skipping to the next city
# Processing Record 432 of 593 | senanga
# Processing Record 433 of 593 | tocopilla
# Processing Record 434 of 593 | vytegra
# Processing Record 435 of 593 | alice springs
# Processing Record 436 of 593 | petropavlovsk-kamchatskiy
# Processing Record 437 of 593 | buenavista
# Processing Record 438 of 593 | nola
# Processing Record 439 of 593 | mayumba
# Processing Record 440 of 593 | jampur
# Processing Record 441 of 593 | tenabo
# Processing Record 442 of 593 | toowoomba
# Processing Record 443 of 593 | puerto cabello
# Processing Record 444 of 593 | lethem
# Processing Record 445 of 593 | anori
# Processing Record 446 of 593 | uhlove
# Processing Record 447 of 593 | nyaunglebin
# Processing Record 448 of 593 | concordia
# Processing Record 449 of 593 | sheridan
# Processing Record 450 of 593 | korem
# Processing Record 451 of 593 | san rafael
# Processing Record 452 of 593 | gazojak
# Processing Record 453 of 593 | khor
# Processing Record 454 of 593 | hobyo
# Processing Record 455 of 593 | clyde river
# Processing Record 456 of 593 | batemans bay
# Processing Record 457 of 593 | bakchar
# Processing Record 458 of 593 | merauke
# Processing Record 459 of 593 | samarai
# Processing Record 460 of 593 | vao
# Processing Record 461 of 593 | naze
# Processing Record 462 of 593 | pimampiro
# Processing Record 463 of 593 | monte patria
# Processing Record 464 of 593 | bati
# Processing Record 465 of 593 | timmins
# Processing Record 466 of 593 | durusu
# Processing Record 467 of 593 | balkhash
# Processing Record 468 of 593 | bagdarin
# Processing Record 469 of 593 | novyy urgal
# Processing Record 470 of 593 | hajipur
# Processing Record 471 of 593 | raudeberg
# City (tambul) not found. Skipping to the next city
# Processing Record 473 of 593 | namatanai
# Processing Record 474 of 593 | radomiresti
# Processing Record 475 of 593 | ratnagiri
# Processing Record 476 of 593 | putina
# Processing Record 477 of 593 | namibe
# City (tabuan) not found. Skipping to the next city
# Processing Record 479 of 593 | vershino-darasunskiy
# Processing Record 480 of 593 | natchitoches
# Processing Record 481 of 593 | xiamen
# Processing Record 482 of 593 | poya
# Processing Record 483 of 593 | leningradskiy
# Processing Record 484 of 593 | westport
# Processing Record 485 of 593 | haines junction
# Processing Record 486 of 593 | ahtopol
# Processing Record 487 of 593 | tanout
# Processing Record 488 of 593 | muisne
# Processing Record 489 of 593 | niksic
# Processing Record 490 of 593 | port hardy
# Processing Record 491 of 593 | imeni poliny osipenko
# Processing Record 492 of 593 | jimo
# Processing Record 493 of 593 | syracuse
# Processing Record 494 of 593 | tallahassee
# City (dujuma) not found. Skipping to the next city
# City (chokwe) not found. Skipping to the next city
# Processing Record 497 of 593 | fort nelson
# Processing Record 498 of 593 | jacareacanga
# City (rungata) not found. Skipping to the next city
# Processing Record 500 of 593 | hastings
# Processing Record 501 of 593 | shache
# Processing Record 502 of 593 | launceston
# Processing Record 503 of 593 | necochea
# Processing Record 504 of 593 | walvis bay
# City (cubarral) not found. Skipping to the next city
# City (safaga) not found. Skipping to the next city
# Processing Record 507 of 593 | tonota
# Processing Record 508 of 593 | zambezi
# Processing Record 509 of 593 | beatrice
# Processing Record 510 of 593 | christchurch
# Processing Record 511 of 593 | lavos
# Processing Record 512 of 593 | sirjan
# Processing Record 513 of 593 | kudahuvadhoo
# Processing Record 514 of 593 | benemerito de las americas
# Processing Record 515 of 593 | mattru
# City (tukrah) not found. Skipping to the next city
# Processing Record 517 of 593 | pedernales
# Processing Record 518 of 593 | les cayes
# Processing Record 519 of 593 | saint-pierre
# Processing Record 520 of 593 | north platte
# Processing Record 521 of 593 | kaitong
# Processing Record 522 of 593 | sao gabriel da cachoeira
# Processing Record 523 of 593 | shipley
# City (turtkul) not found. Skipping to the next city
# Processing Record 525 of 593 | nemuro
# Processing Record 526 of 593 | ola
# City (balykshi) not found. Skipping to the next city
# Processing Record 528 of 593 | chongoyape
# Processing Record 529 of 593 | turbat
# City (axixa do tocantins) not found. Skipping to the next city
# Processing Record 531 of 593 | noumea
# Processing Record 532 of 593 | ulagan
# Processing Record 533 of 593 | kavieng
# Processing Record 534 of 593 | sinnamary
# City (umzimvubu) not found. Skipping to the next city
# City (burkhala) not found. Skipping to the next city
# Processing Record 537 of 593 | ilulissat
# Processing Record 538 of 593 | sokolo
# Processing Record 539 of 593 | adrar
# Processing Record 540 of 593 | green river
# Processing Record 541 of 593 | padang
# Processing Record 542 of 593 | lindi
# Processing Record 543 of 593 | boddam
# Processing Record 544 of 593 | pangkalanbuun
# Processing Record 545 of 593 | caravelas
# Processing Record 546 of 593 | alakurtti
# Processing Record 547 of 593 | avera
# Processing Record 548 of 593 | lerwick
# Processing Record 549 of 593 | chara
# Processing Record 550 of 593 | atherton
# Processing Record 551 of 593 | chinsali
# Processing Record 552 of 593 | santa elena
# Processing Record 553 of 593 | shaunavon
# Processing Record 554 of 593 | kabinda
# Processing Record 555 of 593 | grand gaube
# Processing Record 556 of 593 | tazovskiy
# Processing Record 557 of 593 | oranjemund
# Processing Record 558 of 593 | bintulu
# Processing Record 559 of 593 | zhigansk
# City (shkotovo-26) not found. Skipping to the next city
# Processing Record 561 of 593 | arica
# City (asfi) not found. Skipping to the next city
# Processing Record 563 of 593 | pitimbu
# Processing Record 564 of 593 | okakarara
# Processing Record 565 of 593 | hajduhadhaz
# Processing Record 566 of 593 | zhangye
# Processing Record 567 of 593 | carahue
# Processing Record 568 of 593 | masinigudi
# City (marang) not found. Skipping to the next city
# Processing Record 570 of 593 | henties bay
# Processing Record 571 of 593 | muli
# City (pemangkat) not found. Skipping to the next city
# Processing Record 573 of 593 | rexburg
# Processing Record 574 of 593 | hambantota
# Processing Record 575 of 593 | sampit
# Processing Record 576 of 593 | grand-lahou
# City (rudbar) not found. Skipping to the next city
# Processing Record 578 of 593 | nangomba
# Processing Record 579 of 593 | kasongo
# Processing Record 580 of 593 | lata
# Processing Record 581 of 593 | klyuchi
# Processing Record 582 of 593 | tessalit
# Processing Record 583 of 593 | liusha
# Processing Record 584 of 593 | afua
# Processing Record 585 of 593 | ketchikan
# Processing Record 586 of 593 | ngunguru
# Processing Record 587 of 593 | slave lake
# Processing Record 588 of 593 | veere
# City (mouzakion) not found. Skipping to the next city
# Processing Record 590 of 593 | kamina
# Processing Record 591 of 593 | olonets
# City (sinkat) not found. Skipping to the next city
# Processing Record 593 of 593 | udachnyy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# CLEAN THE DATA!
# format the date:
fmt_date_list = pd.to_datetime(unfmt_date_list, unit = 's')
fmt_date_list

# format the max temp from kelvin to fahrenheit:
fmt_max_t_list = []
for x in max_t_list:
    fmt_max_t_list.append(pytemperature.k2f(x))
fmt_max_t_list

# Create a dictionary:
weather_dict = {
    'City': city_list,
    'Cloudiness': cloudiness_list,
    'Country': country_list,
    'Date': fmt_date_list,
    'Humidity': humidity_list,
    'Lat': lat_list,
    'Lng': lng_list,
    'Max Temp': fmt_max_t_list,
    'Wind Speed': windspeed_list
}


# Create Data Frame:
weather_df = pd.DataFrame(weather_dict)

weather_df.count()
# Out:
# City          523
# Cloudiness    523
# Country       523
# Date          523
# Humidity      523
# Lat           523
# Lng           523
# Max Temp      523
# Wind Speed    523
# dtype: int64

# %%
# Export to csv:
# weather_df.to_csv(output_data_file, header = True, mode = 'w', index = False)

# display the data frame:
# weather_df.head()
   
html_table = weather_df.to_html()    
html_table_final = html_table.replace('\n', '')
html_table_final
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City</th>      <th>Cloudiness</th>      <th>Country</th>      <th>Date</th>      <th>Humidity</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Wind Speed</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Komsomolskiy</td>      <td>100</td>      <td>RU</td>      <td>2019-08-12 03:15:44</td>      <td>75</td>      <td>67.55</td>      <td>63.78</td>      <td>39.55</td>      <td>5.60</td>    </tr>    <tr>      <th>1</th>      <td>Port Alfred</td>      <td>55</td>      <td>ZA</td>      <td>2019-08-12 03:15:45</td>      <td>66</td>      <td>-33.59</td>      <td>26.89</td>      <td>56.98</td>      <td>2.68</td>    </tr>    <tr>      <th>2</th>      <td>Valera</td>      <td>0</td>      <td>VE</td>      <td>2019-08-12 03:15:45</td>      <td>72</td>      <td>9.31</td>      <td>-70.61</td>      <td>81.68</td>      <td>2.08</td>    </tr>    <tr>      <th>3</th>      <td>Vanimo</td>      <td>95</td>      <td>PG</td>      <td>2019-08-12 03:15:46</td>      <td>77</td>      <td>-2.67</td>      <td>141.30</td>      <td>81.68</td>      <td>5.69</td>    </tr>    <tr>      <th>4</th>      <td>Bathsheba</td>      <td>40</td>      <td>BB</td>      <td>2019-08-12 03:15:46</td>      <td>83</td>      <td>13.22</td>      <td>-59.52</td>      <td>78.78</td>      <td>3.60</td>    </tr>    <tr>      <th>5</th>      <td>Flin Flon</td>      <td>42</td>      <td>CA</td>      <td>2019-08-12 03:15:47</td>      <td>64</td>      <td>54.77</td>      <td>-101.88</td>      <td>57.38</td>      <td>0.89</td>    </tr>    <tr>      <th>6</th>      <td>Rikitea</td>      <td>100</td>      <td>PF</td>      <td>2019-08-12 03:15:47</td>      <td>84</td>      <td>-23.12</td>      <td>-134.97</td>      <td>72.85</td>      <td>7.69</td>    </tr>    <tr>      <th>7</th>      <td>Albany</td>      <td>20</td>      <td>US</td>      <td>2019-08-12 03:12:11</td>      <td>68</td>      <td>42.65</td>      <td>-73.75</td>      <td>66.97</td>      <td>2.76</td>    </tr>    <tr>      <th>8</th>      <td>Mar del Plata</td>      <td>0</td>      <td>AR</td>      <td>2019-08-12 03:15:47</td>      <td>59</td>      <td>-46.43</td>      <td>-67.52</td>      <td>30.02</td>      <td>6.24</td>    </tr>    <tr>      <th>9</th>      <td>Georgetown</td>      <td>40</td>      <td>GY</td>      <td>2019-08-12 03:14:22</td>      <td>94</td>      <td>6.80</td>      <td>-58.16</td>      <td>78.78</td>      <td>2.10</td>    </tr>    <tr>      <th>10</th>      <td>Port Lincoln</td>      <td>100</td>      <td>AU</td>      <td>2019-08-12 03:15:48</td>      <td>65</td>      <td>-34.72</td>      <td>135.86</td>      <td>52.15</td>      <td>4.00</td>    </tr>    <tr>      <th>11</th>      <td>Busselton</td>      <td>0</td>      <td>AU</td>      <td>2019-08-12 03:15:48</td>      <td>35</td>      <td>-33.64</td>      <td>115.35</td>      <td>67.98</td>      <td>9.65</td>    </tr>    <tr>      <th>12</th>      <td>Cedar City</td>      <td>1</td>      <td>US</td>      <td>2019-08-12 03:15:49</td>      <td>30</td>      <td>37.68</td>      <td>-113.06</td>      <td>69.78</td>      <td>3.60</td>    </tr>    <tr>      <th>13</th>      <td>San Patricio</td>      <td>34</td>      <td>PY</td>      <td>2019-08-12 03:15:49</td>      <td>86</td>      <td>-26.98</td>      <td>-56.83</td>      <td>61.70</td>      <td>2.09</td>    </tr>    <tr>      <th>14</th>      <td>Severo-Kurilsk</td>      <td>59</td>      <td>RU</td>      <td>2019-08-12 03:15:49</td>      <td>96</td>      <td>50.68</td>      <td>156.12</td>      <td>49.45</td>      <td>6.66</td>    </tr>    <tr>      <th>15</th>      <td>Constitucion</td>      <td>40</td>      <td>MX</td>      <td>2019-08-12 03:15:50</td>      <td>49</td>      <td>23.99</td>      <td>-104.67</td>      <td>71.58</td>      <td>4.60</td>    </tr>    <tr>      <th>16</th>      <td>Nokaneng</td>      <td>0</td>      <td>BW</td>      <td>2019-08-12 03:15 ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker = 'o', color = 'blue', edgecolor = 'black')

plt.title(f"City Latitude vs Max Temperature ({time.strftime('%m') + '/' + time.strftime('%d') + '/' + time.strftime('%y')})")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('Latitude_vs_MaxTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker = 'o', color = 'blue', edgecolor = 'black')

plt.title(f"City Latitude vs Humidity ({time.strftime('%m') + '/' + time.strftime('%d') + '/' + time.strftime('%y')})")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('Latitude_vs_Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker = 'o', color = 'blue', edgecolor = 'black')

plt.title(f"City Latitude vs Cloudiness ({time.strftime('%m') + '/' + time.strftime('%d') + '/' + time.strftime('%y')})")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('Latitude_vs_Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker = 'o', color = 'blue', edgecolor = 'black')

plt.title(f"City Latitude vs Wind Speed ({time.strftime('%m') + '/' + time.strftime('%d') + '/' + time.strftime('%y')})")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
plt.savefig('Latitude_vs_WindSpeed.png')

# %%
# * You must include a written description of three observable trends based on the data.

# 1. Latitude vs. Temperature Plot

#     The closer the city is to the equator, the hotter the temperature. 
#     It also appears that there are more cities between the equator and latitude 
#     20 than there are between the equator and latitude -20, meaning there are 
#     more cities in the northern side of the equator.

# 2. Latitude vs. Humidity Plot

#     Humidity seems generally high for cities in all latitudes. Perhaps this is 
#     because us human beings need some level of humidity to survive. Again, it 
#     looks like there is a general trend for the northern cities to have high 
#     humidity. The desert areas are typically uninhabitable, so perhaps people 
#     tend to live in more northern areas. 

# 3. Latitude vs. Cloudiness Plot

#     There is no correlation here because the plots are much too scattered.

# 4. Latitude vs. Wind Speed Plot

#     The majorty of the cities are located in low wind speed areas in all latitudes. 
#     This would make sense from a survival perspective as well: It would be 
#     difficult to live in super windy locations. 

# Lastly, it would be interesting to investigate if there is a correlation between 
# temperature and humidity or between cloudiness and humidity. I may be wrong but 
# I would expect to see more cities in high temperature and high humidity than high 
# temperature and low humidity. As for the cloudiness factor: I would expect to see
# high cloudiness correlate with high humidity. But again, I may be wrong, so this 
# would be interesting to investigate next.
